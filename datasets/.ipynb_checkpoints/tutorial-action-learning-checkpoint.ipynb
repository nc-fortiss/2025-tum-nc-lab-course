# %% [markdown]
# # Tutorial on Online Learning of Actions from Event Camera Streams

# %% [markdown]
# This tutorial introduces you to:
# - Event-based action recognition dataset THU-EACT-50
# - Pretraining pipeline for SNN feature extractor
# - Evaluation of the feature extractor for new action classes
# - Online Learning of new action classes with CLP

# %% [markdown]
# # Motivation
#
# ![Motivation](img/adaptive_ml.png)

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as display
from IPython.display import Image
from matplotlib import animation
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier, NearestCentroid
from sklearn import metrics
from sklearn.manifold import TSNE
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Dataset THU-EACT-50
#
# Contribution from :
#
# > Y. Gao et al., "Action Recognition and Benchmark Using Event Cameras," in IEEE Transactions on Pattern Analysis and Machine Intelligence, vol. 45, no. 12, pp. 14081-14097, Dec. 2023.
#
# The dataset class follows standard torch dataset definition. They are defined in `thu_eact_50.py`. We will just import the dataset here.
#
# Important facts:
#
# - 50 event-specific action categories
# - 105 socially recruited subjects
# - 10,500 video recordings
# - CeleX-V event camera with a spatial resolution of 1280x800
# - Two oblique front views of the actor

# %% [markdown]
# ![Dataset](img/list_of_actions.png)

# %%
from datasets.thu_eact_50 import THU_EACT_50

# %%
sampling_time = 2
sample_length = 1000
ds_factor = 6 
repr = ['myCount']
aug = True

# %%
data_directory = "/home/neumeier/Documents/spiking_body/thu_data/THU-EACT-50-Mini"

# %%
training_set = THU_EACT_50(path=data_directory, mode="mini", train=True, augmentation=aug, repr=repr,
                           sampling_time=sampling_time, sample_length=sample_length, ds_factor=ds_factor, 
                           center_crop=True)

# %%
testing_set = THU_EACT_50(path=data_directory, mode="mini", train=False, augmentation=False, repr=repr,
                          sampling_time=sampling_time, sample_length=sample_length, ds_factor=ds_factor, 
                          center_crop=True)

# %% [markdown]
# Let's visualize the data

# %%
from utils.io import tensor_to_event

# %%
for i in range(4):
    spike_tensor, label = testing_set[5*i]
    spike_tensor = spike_tensor.reshape(2, 100, 100, -1)
    event = tensor_to_event(spike_tensor.cpu().data.numpy())
    #event.t = event.t * sampling_time
    event.t = event.t * sampling_time * 10
    anim = event.anim(plt.figure(figsize=(5, 5)), frame_rate=20)
    anim.save(f'gifs/test_thu_eact_{i}.gif', animation.PillowWriter(fps=20), dpi=300)
    print("Sample: ", i, "Label: ", label)
# Out:
# Sample:  0 Label:  20
# Sample:  1 Label:  29
# Sample:  2 Label:  42
# Sample:  3 Label:  45

# %%
gif_td = lambda gif: f'<td> <img src="{gif}" alt="Drawing" style="height: 250px;"/> </td>'

# %%
header = '<table><tr>'
images = ' '.join([gif_td(f'gifs/thu_eact_{i}.gif') for i in range(4)])
footer = '</tr></table>'
display.HTML(header + images + footer)
# Out:
# <table><tr><td> <img src="gifs/thu_eact_0.gif" alt="Drawing" style="height: 250px;"/> </td> <td> <img src="gifs/thu_eact_1.gif" alt="Drawing" style="height: 250px;"/> </td> <td> <img src="gifs/thu_eact_2.gif" alt="Drawing" style="height: 250px;"/> </td> <td> <img src="gifs/thu_eact_3.gif" alt="Drawing" style="height: 250px;"/> </td></tr></table>

# %% [markdown]
# # SNN Feature Extractor

# %% [markdown]
# Now, we set up the SNN feature extractor

# %%
from models.plif_models import AllConvPLIFSNN, AllConvPLIFLISNN

# %%
device = torch.device('cpu')
#device = torch.device('cuda')

# model hyperparams
inp_features = 2
channels = 8
feat_neur = 512
classes = 25
dropout = 0.1
pretrain = True

# %%
net = AllConvPLIFSNN(inp_features, channels, feat_neur, classes, 
                     delay=False, dropout=dropout, quantize=False, 
                     pretrain=pretrain, device=device).to(device)
# Out:
# WARNING:root:Trying to set the step mode for AllConvPLIFSNN(
#   (feature_extractor): ModuleList(
#     (0): Conv2d(2, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False, step_mode=s)
#     (1): BatchNorm2d(8, eps=0.001, momentum=0.01, affine=True, track_running_stats=True, step_mode=s)
#     (2): ParametricLIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=s, backend=torch, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#     (3): Dropout(p=0.1)
#     (4): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False, step_mode=s)
#     (5): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True, step_mode=s)
#     (6): ParametricLIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=s, backend=torch, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#     (7): Dropout(p=0.1)
#     (8): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False, step_mode=s)
#     (9): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True, step_mode=s)
#     (10): ParametricLIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=s, backend=torch, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#     (11): Dropout(p=0.1)
#     (12): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), bias=False, step_mode=s)
#     (13): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True, step_mode=s)
#     (14): ParametricLIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=s, backend=torch, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#     (15): Dropout(p=0.1)
#     (16): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, step_mode=s)
#     (17): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True, step_mode=s)
#     (18): ParametricLIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=s, backend=torch, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#     (19): Dropout(p=0.1)
#     (20): Flatten(start_dim=1, end_dim=-1, step_mode=s)
#     (21): Linear(in_features=2304, out_features=512, bias=False)
#     (22): ParametricLIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=True, step_mode=s, backend=torch, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#   )
#   (classifier): Linear(in_features=512, out_features=25, bias=False)
#   (projection): Sequential(
#     (0): Linear(in_features=512, out_features=128, bias=True)
#     (1): ReLU()
#   )
# ), which is not spikingjelly.activation_based.base.StepModule
# WARNING:root:Dropout(p=0.1) does not supports for backend=cupy. It will still use backend=torch.
# WARNING:root:Dropout(p=0.1) does not supports for backend=cupy. It will still use backend=torch.
# WARNING:root:Dropout(p=0.1) does not supports for backend=cupy. It will still use backend=torch.
# WARNING:root:Dropout(p=0.1) does not supports for backend=cupy. It will still use backend=torch.
# WARNING:root:Dropout(p=0.1) does not supports for backend=cupy. It will still use backend=torch.

# %% [markdown]
# # Feature Extractor Training
#
# The next step is the training of the SNN feature extractor on the selected dataset split.
# This takes a few hours. Hence, we prepared trained models and also saved features for known and unkown action classes.

# %%
loop

# %% [markdown]
# # Feature Extractor Evaluation
#
# Here we select one of the prepared SNN feature extractors and evaluate the quality of its features.

# %%
folder = 'trained/Pretrained_thu_eact_50_scnn_ds6_plif_38actions_myCnt_aug_2ms/'

# %%
with open(folder + 'features_known_train_full.npy', 'rb') as f:
    X_k_train = np.load(f)
    y_k_train = np.load(f)

with open(folder + 'features_known_test_full.npy', 'rb') as f:
    X_k_test = np.load(f)
    y_k_test = np.load(f)

with open(folder + 'features_unknown_train_full.npy', 'rb') as f:
    X_u_train = np.load(f)
    y_u_train = np.load(f)

with open(folder + 'features_unknown_test_full.npy', 'rb') as f:
    X_u_test = np.load(f)
    y_u_test = np.load(f)

# %% [markdown]
# Test for known action classes:

# %%
# known actions
unique_labels, counts = np.unique(y_k_train, return_counts=True)
num_classes = len(unique_labels)
X_k_train = X_k_train / np.linalg.norm(X_k_train, axis=1, keepdims=True)
X_k_test = X_k_test / np.linalg.norm(X_k_test, axis=1, keepdims=True)
X_unknown = np.concatenate([X_k_train, X_k_test]) 

n_samples_per_cls = X_unknown.shape[0]/num_classes

n_tr_samples = len(y_k_train) 
n_test_samples = len(y_k_test) 

y_train = y_k_train[:n_tr_samples]
y_test = y_k_test[:n_test_samples]
y_unknown = np.concatenate([y_train, y_test])

# %% [markdown]
# Test for unknown action classes:

# %%
# unknown actions
unique_labels, counts = np.unique(y_u_train, return_counts=True)
num_classes = len(unique_labels)
X_u_train = X_u_train / np.linalg.norm(X_u_train, axis=1, keepdims=True)
X_u_test = X_u_test / np.linalg.norm(X_u_test, axis=1, keepdims=True)
X_unknown = np.concatenate([X_u_train, X_u_test]) 

n_samples_per_cls = X_unknown.shape[0]/num_classes

n_tr_samples = len(y_u_train) 
n_test_samples = len(y_u_test) 

y_train = y_u_train[:n_tr_samples]
y_test = y_u_test[:n_test_samples]
y_unknown = np.concatenate([y_train, y_test])

# %%
num_classes
# Out:
# 12

# %%
X_tsne = TSNE(n_components=2, learning_rate='auto', n_jobs=-1, n_iter_without_progress=600, 
              verbose=2,init='pca', perplexity=n_samples_per_cls, 
              n_iter=1000, metric='cosine', random_state=4).fit_transform(X_unknown)
# Out:
# [t-SNE] Computing 631 nearest neighbors...
# [t-SNE] Indexed 2520 samples in 0.001s...
# [t-SNE] Computed neighbors for 2520 samples in 0.453s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2520
# [t-SNE] Computed conditional probabilities for sample 2000 / 2520
# [t-SNE] Computed conditional probabilities for sample 2520 / 2520
# [t-SNE] Mean sigma: 0.062834
# [t-SNE] Computed conditional probabilities in 0.475s
# [t-SNE] Iteration 50: error = 57.7510910, gradient norm = 0.0214558 (50 iterations in 1.031s)
# [t-SNE] Iteration 100: error = 56.0840073, gradient norm = 0.0000642 (50 iterations in 1.192s)
# [t-SNE] Iteration 150: error = 56.0839729, gradient norm = 0.0000521 (50 iterations in 0.817s)
# [t-SNE] Iteration 200: error = 56.0839653, gradient norm = 0.0000517 (50 iterations in 0.865s)
# [t-SNE] Iteration 250: error = 56.0839767, gradient norm = 0.0000526 (50 iterations in 0.796s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 56.083977
# [t-SNE] Iteration 300: error = 1.0703241, gradient norm = 0.0315385 (50 iterations in 0.844s)
# [t-SNE] Iteration 350: error = 0.7698428, gradient norm = 0.0086726 (50 iterations in 0.908s)
# [t-SNE] Iteration 400: error = 0.7293371, gradient norm = 0.0060245 (50 iterations in 0.880s)
# [t-SNE] Iteration 450: error = 0.7152074, gradient norm = 0.0043229 (50 iterations in 0.889s)
# [t-SNE] Iteration 500: error = 0.7088874, gradient norm = 0.0032816 (50 iterations in 0.910s)
# [t-SNE] Iteration 550: error = 0.7055597, gradient norm = 0.0026579 (50 iterations in 0.911s)
# [t-SNE] Iteration 600: error = 0.7034490, gradient norm = 0.0021126 (50 iterations in 0.917s)
# [t-SNE] Iteration 650: error = 0.7025014, gradient norm = 0.0010385 (50 iterations in 1.001s)
# [t-SNE] Iteration 700: error = 0.7018490, gradient norm = 0.0007802 (50 iterations in 0.902s)
# [t-SNE] Iteration 750: error = 0.7015841, gradient norm = 0.0006170 (50 iterations in 0.925s)
# [t-SNE] Iteration 800: error = 0.7013986, gradient norm = 0.0005064 (50 iterations in 0.916s)
# [t-SNE] Iteration 850: error = 0.7013842, gradient norm = 0.0003991 (50 iterations in 0.926s)
# [t-SNE] Iteration 900: error = 0.7012841, gradient norm = 0.0001992 (50 iterations in 0.899s)
# [t-SNE] Iteration 950: error = 0.7012511, gradient norm = 0.0002350 (50 iterations in 0.866s)
# [t-SNE] Iteration 1000: error = 0.7011762, gradient norm = 0.0001904 (50 iterations in 0.895s)
# [t-SNE] KL divergence after 1000 iterations: 0.701176

# %%
df = pd.DataFrame()
df["y"] = y_unknown
df["comp-1"] = X_tsne[:n_tr_samples+n_test_samples,0]
df["comp-2"] = X_tsne[:n_tr_samples+n_test_samples,1]

df_train = df.iloc[range(len(y_train)), :]
df_train = df_train.iloc[:n_tr_samples]

df_test = df.iloc[range(len(y_train),len(y_unknown)), :]
df_test = df_test.iloc[:n_test_samples]

df_conc = pd.concat([df_test.assign(dataset='test'), df_train.assign(dataset='train')])
# df_train = df_train.iloc[np.argsort(y_u_train),:]
plt.figure(figsize=(12,12))
sns.scatterplot(x="comp-1", y="comp-2", hue=df_conc.y.tolist(), style='dataset', s=60,
                palette=sns.color_palette("hls", num_classes),
                legend=True, data=df_conc).set(title="THU-EACT-50 actions T-SNE projection") #"hls", 
ax=plt.gca()
#plt.savefig(folder + "/tsne_known_proj.png", bbox_inches='tight')

# %% [markdown]
# # Offline Classification Tests

# %% [markdown]
# Test for known action classes:

# %%
X_train = X_k_train
y_train = y_k_train
X_test = X_k_test
y_test = y_k_test

# %% [markdown]
# Test for unknown action classes:

# %%
X_train = X_u_train
y_train = y_u_train
X_test = X_u_test
y_test = y_u_test

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
clf = svm.SVC(max_iter=100000, kernel='linear', class_weight='balanced')
clf.fit(X_train_scaled, y_train)
y_pred=clf.predict(X_train_scaled)
print('SVM (Linear)')
print("Training accuracy", np.round(metrics.accuracy_score(y_train, y_pred),2))
y_pred=clf.predict(X_test_scaled)
print("Test accuracy    ", np.round(metrics.accuracy_score(y_test, y_pred),2))
 
print('------------------------------------')
clf = KNeighborsClassifier(n_neighbors=1, n_jobs=8, metric='cosine')
print('KNN (k=1)')
clf.fit(X_train, y_train)
y_pred=clf.predict(X_train)
print("Training accuracy", np.round(metrics.accuracy_score(y_train, y_pred),2))
y_pred=clf.predict(X_test)
print("Test accuracy    ", np.round(metrics.accuracy_score(y_test, y_pred),2))
 
print('------------------------------------')
clf = KNeighborsClassifier(n_neighbors=10, n_jobs=8, metric='cosine')
print('KNN (k=10)')
clf.fit(X_train, y_train)
y_pred=clf.predict(X_train)
print("Training accuracy", np.round(metrics.accuracy_score(y_train, y_pred),2))
y_pred=clf.predict(X_test)
print("Test accuracy    ", np.round(metrics.accuracy_score(y_test, y_pred),2))
 
print('------------------------------------')
clf = NearestCentroid(metric='euclidean')
print('NCM (euclidean)')
clf.fit(X_train, y_train)
y_pred=clf.predict(X_train)
print("Training accuracy", np.round(metrics.accuracy_score(y_train, y_pred),2))
y_pred=clf.predict(X_test)
print("Test accuracy    ", np.round(metrics.accuracy_score(y_test, y_pred),2))
# Out:
# SVM (Linear)
# Training accuracy 1.0
# Test accuracy     0.95
# ------------------------------------
# KNN (k=1)
# Training accuracy 1.0
# Test accuracy     0.9
# ------------------------------------
# KNN (k=10)
# Training accuracy 0.94
# Test accuracy     0.91
# ------------------------------------
# NCM (euclidean)
# Training accuracy 0.88
# Test accuracy     0.85

# %% [markdown]
# # CLP Training

# %%
from utils.torch_clp import ContinuallyLearningPrototypes

# %%
clf = ContinuallyLearningPrototypes(
                 input_shape=X_train.shape[1],
                 backbone=None,
                 sim_metric='dot_product',
                 n_protos=500,
                 num_classes=50,
                 alpha_init=1,
                 sim_th_init=0.8, # -> higher, e.g 0.7
                 n_wta=5,
                 k_hit=1,
                 k_miss=0.5,
                 tau_sim_th_pos=100,
                 tau_sim_th_neg=100,
                 k_sim_th_pos=0.9,
                 k_sim_th_neg=1.1,
                 device='cpu',
                 supervised=True,
                 adaptive_th=False,
                 adaptive_protos=False, #True,
                 learn_outliers=True,
                 verbose=1
)

# %%
X_u_train_normed_t = torch.tensor(X_train)
X_u_test_normed_t = torch.tensor(X_test)
y_train_normed_t = torch.tensor(y_train)
y_test_normed_t = torch.tensor(y_test)

# %%
train_samples = X_u_train_normed_t.shape[0]
#train_samples = 50

# %%
for i in range(train_samples):
    clf.fit(X_u_train_normed_t[i], y_train_normed_t[i])
# Out:
# Novel Label!
# Novel Label!
# Correct winner!
# Label tensor(19)
# Novel Label!
# Novel Label!
# Novel Label!
# Novel Label!
# Novel Label!
# Novel Label!
# Novel Label!
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(43)
# Novel Label!
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(23)
# Novel Label!
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Novel Label!
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(7)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(7)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(3)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(3)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(3)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(3)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(3)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(3)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(7)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(47)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(3)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(3)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(7)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(39)
# ...
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(47)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(11)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(31)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(11)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(39)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(3)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(35)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Wrong winner, allocate novel instance!
# Label tensor(35)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(47)
# Wrong winner, allocate novel instance!
# Label tensor(43)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(19)
# Correct winner!
# Label tensor(19)
# Wrong winner, allocate novel instance!
# Label tensor(39)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(43)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(39)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(15)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(7)
# Correct winner!
# Label tensor(31)
# Wrong winner, allocate novel instance!
# Label tensor(7)
# Wrong winner, allocate novel instance!
# Label tensor(15)
# Wrong winner, allocate novel instance!
# Label tensor(27)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(11)
# Correct winner!
# Label tensor(47)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(3)
# Correct winner!
# Label tensor(31)
# Correct winner!
# Label tensor(19)
# Correct winner!
# Label tensor(23)
# Correct winner!
# Label tensor(35)
# Correct winner!
# Label tensor(23)
# Wrong winner, allocate novel instance!
# Label tensor(23)
# Correct winner!
# Label tensor(39)

# %%
pred=clf.predict(X_u_train_normed_t, return_probas=False, thresholded=False, return_sims=False)
y_pred = torch.argmax(pred, dim=1)
metrics.accuracy_score(y_train_normed_t.numpy(), y_pred.numpy())
# Out:
# 0.961764705882353

# %%
y_train_original = y_train_normed_t.numpy() #+ 25 #* 4 + 3
y_pred_original = y_pred.numpy() #+ 25 #* 4 + 3
display_labels = np.unique(y_pred_original)

# %%
cm = confusion_matrix(y_train_original, y_pred_original)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax)

plt.show()

# %%
pred=clf.predict(X_u_test_normed_t, return_probas=False, thresholded=False, return_sims=False)
y_pred = torch.argmax(pred, dim=1)
metrics.accuracy_score(y_test_normed_t.numpy(), y_pred.numpy())
# Out:
# 0.85

# %%
y_test_original = y_test_normed_t.numpy()
y_pred_original = y_pred.numpy()

# %%
cm = confusion_matrix(y_test_original, y_pred_original)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax)

plt.show()
